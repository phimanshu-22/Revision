# %%
from config import*
from models import*
from Poisson import*
# Out:
# /envs/common/lib/python3.10/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
from PINN import*


PINN_model = PINN(num_hidden_layers = 6,  hidden_neurons = 200).to(device)

optimizer1_PINN = optim.Adam(PINN_model.parameters(), lr=1e-4)

optimizer2_PINN = torch.optim.LBFGS(PINN_model.parameters(), 
                             lr=1.0,
                             max_iter=10**10,
                             max_eval=10**10,
                             tolerance_grad=1e-09,
                             tolerance_change=1e-10,
                             history_size=50,
                             line_search_fn="strong_wolfe")

train_pinn(model = PINN_model,
                    optimizer1 = optimizer1_PINN, 
                    optimizer2 = optimizer2_PINN,
                    num_epochs = 10**4+1, 
                    num_prints = 10)
# Out:
# ======================== ADAM phase Training ========================
#   0%|          | 3/10001 [00:00<22:11,  7.51it/s]
# Epoch[0]  Total Loss: 8813.293945, PDE Loss: 8813.181641, BC Loss: 0.112680
# 		RelativeL2: 1.016471266746521,	Max: 1.0892572402954102
#  10%|█         | 1003/10001 [02:14<17:01,  8.81it/s]
# Epoch[1000]  Total Loss: 10.907639, PDE Loss: 10.230979, BC Loss: 0.676659
# 		RelativeL2: 0.49423977732658386,	Max: 1.1395518779754639
#  20%|██        | 2003/10001 [04:13<15:07,  8.82it/s]
# Epoch[2000]  Total Loss: 2.908101, PDE Loss: 2.430066, BC Loss: 0.478036
# 		RelativeL2: 0.3461962044239044,	Max: 1.1512547731399536
#  30%|███       | 3003/10001 [06:12<13:12,  8.83it/s]
# Epoch[3000]  Total Loss: 1.571150, PDE Loss: 1.178037, BC Loss: 0.393113
# 		RelativeL2: 0.30640271306037903,	Max: 1.1123991012573242
#  40%|████      | 4003/10001 [08:11<11:18,  8.84it/s]
# Epoch[4000]  Total Loss: 1.063647, PDE Loss: 0.739423, BC Loss: 0.324224
# ...
