# %%
from config import*
from models import*
from Poisson import*
# Out:
# /envs/common/lib/python3.10/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
from WPINN_Poisson import*


WPINN_model = WPINN(input_size = n_collocation, 
                    num_hidden_layers1 = 3, 
                    num_hidden_layers2 = 6, 
                    hidden_neurons = 50, 
                    family_size = len_family).to(device)

optimizer1_WPINN = optim.Adam(WPINN_model.parameters(), lr=1e-4)

optimizer2_WPINN = torch.optim.LBFGS(WPINN_model.parameters(), 
                             lr=1.0,
                             max_iter=10**10,
                             max_eval=10**10,
                             tolerance_grad=1e-09,
                             tolerance_change=1e-10,
                             history_size=50,
                             line_search_fn=None)

coeff, bias = train_wpinn(model = WPINN_model,
                          optimizer1 = optimizer1_WPINN, 
                          optimizer2 = optimizer2_WPINN,
                          num_epochs = 10**4+1, 
                          num_prints = 10)
# Out:
# ======================== Computing Wavelet Family ========================
#
# family_len:  97336
#
# ======================== ADAM phase Training ========================
#   0%|          | 9/10001 [00:00<06:25, 25.90it/s]
# Epoch[0]  Total Loss: 9331.765625, PDE Loss: 9330.310547, BC Loss: 1.454726
# 		RelativeL2: 1.6865394115447998,	Max: 1.4973682165145874
#  10%|█         | 1009/10001 [00:53<08:02, 18.66it/s]
# Epoch[1000]  Total Loss: 0.526339, PDE Loss: 0.329922, BC Loss: 0.196417
# 		RelativeL2: 0.2827739119529724,	Max: 0.3758222758769989
#  20%|██        | 2009/10001 [01:46<07:07, 18.68it/s]
# Epoch[2000]  Total Loss: 0.859329, PDE Loss: 0.681288, BC Loss: 0.178041
# 		RelativeL2: 0.26403504610061646,	Max: 0.3981438875198364
#  30%|███       | 3009/10001 [02:40<06:06, 19.08it/s]
# Epoch[3000]  Total Loss: 0.303077, PDE Loss: 0.139513, BC Loss: 0.163564
# 		RelativeL2: 0.25292637944221497,	Max: 0.4020230770111084
#  40%|████      | 4009/10001 [03:33<05:14, 19.03it/s]
# ...
